# %% [markdown]
# **These days, NFTs are making a splash in the market by providing people with a new option to acquire assets. Between the second and third quarter of 2021, NFT trading increased 700% ($10.7 billion) according to DappRadar.**
#
# **whether they’ve been used for exchanges or as investments, NFTs have been applied to various fields, including science, technology, and art. With NFTs becoming more popular, RMDS Lab is announcing its next data science competition - Creating a NFT Value Dashboard to Summarize the Past and Predict the Future.**
#
# **Contestants will be challenged with collecting datasets to create a dashboard that assesses trends in the development of NFTs and forecast their future trajectory.**

# %% [markdown]
# Evaluation
# Impact: What useful business insights are acquired from the proposal? How does this submitted model benefit (or cost) businesses, and what actionable steps are recommended to improve their work?​
#
# Methodology Valdity: Document the methodology, mathematics, and economic principles behind the proposal and provide the references or reasoning for your approach. How is the prediction generated and how are the factors weighted sensible? Are the assumptions and limitations of the methodology clearly outlined with suggestions to improve the proposal? Are the quantitative steps of data ingestion, feature engineering, model architecture, and performance optimization valid? How robust is your model?
#
# Reproducibility: Does the solution use coding best practices with workflows and documentation to reproduce one’s work? Are the data ingress and egress pipelines reproducible? Is there a clear presentation of data science work in the documentation?
#
# Usability: Is the information presented in a way that is actionable? Would a member of the general public understand the model, what it means, and what actions to take?
#
# Ability to Deploy:Is getting access to the data realistic? How long is the computation time? How well is the scalability of the system to accept new data sources? How often does it need to be maintained? Is it    hard to maintain/update? How much manpower, time, resources are needed to be allocated to maintain the functionality?
#
# Fair and Ethical Use of Data: Does the solution consider biases in data? Is the data from open and trusted sources?
#
# Innovation: Will the idea have a big impact? How innovative is the approach, selection and weighting of various factors, or how information is displayed and communicated?

# %% [markdown]
# Sample Research Questions
#
# - NFT investors and buyers may want to know:
#
# - What types of NFTs are higher valued than others?
# - What types of NFTs have their values going up?​
# - What science & tech NFTs are popular?
# - What types of science & technology IPs are in demand and enjoy a value uptrend?
# - Can we build a financial/ML model to forecast the price of NFTs encrypted by ourselves?
# - Which cryptocurrency is trending recently?
# - Why could some NFTs be sold at a huge price?
# - What types of NFTs are most encrypted by the general public?
# - What are the main differences in NFT transactions among some major marketplaces?
# - What's the best listing duration for a timed auction?
# - What’s the most acceptable price range for our listings to finish a deal?
# - How do you predict the future of the NFT transactions?

# %% [markdown]
# Feature Name	Feature Description
# - primary_asset_contracts_address	The asset contracts address that is associated with this collection
# - primary_asset_contracts_asset_contract_type	The asset contracts type that is associated with this collection. Can be non-fungible or semi-fungible
#
# - primary_asset_contracts_created_date	The created date of the asset contract that is associated with this collection
# - primary_asset_contracts_name	The contract name of the asset that is associated with this collection
# - primary_asset_contracts_nft_version	The NFT version of the asset contract that is associated with this collection
# - primary_asset_contracts_owner	The owner ID of the asset contract that is associated with this collection
# - primary_asset_contracts_schema_name	The shema version that the asset contract used which is associated with the collection. Can be ERC721, ERC1155 etc
#
# - primary_asset_contracts_symbol	The symbol of the asset contract that is associated with this collection
# - primary_asset_contracts_total_supply	The total number of supply in the asset contract that is associated with this collection
# - primary_asset_contracts_description	The description of the asset contract that is associated with this collection
# - primary_asset_contracts_dev_seller_fee_basis_points	The collector's fees that get paid out to them when sales (including re-sales) are made for their collections. One basis point equals to 0.0001
# - primary_asset_contracts_seller_fee_basis_points	The seller fees in the sales. One basis point equals to 0.0001
# - primary_asset_contracts_payout_address	The payout address for the collection's royalties

# %% [markdown]
# stats_one_day_volume	The one day trade volume in this collection. The timestamp of the data collected is on stats_time
# stats_one_day_change	The one day trade volume change in this collection. The timestamp of the data collected is on stats_time
# stats_one_day_sales	The one day number of sales in this collection. The timestamp of the data collected is on stats_time
# stats_one_day_average_price	The one day average price of the items in this collection. The timestamp of the data collected is on stats_time
# stats_seven_day_volume	The seven days trade volume in this collection. The timestamp of the data collected is on stats_time
# stats_seven_day_change	The seven days trade volume change in this collection. The timestamp of the data collected is on stats_time
# stats_seven_day_sales	The seven days number of sales in this collection. The timestamp of the data collected is on stats_time
# stats_seven_day_average_price	The seven days average price of the items in this collection. The timestamp of the data collected is on stats_time

# %% [markdown]
# - stats_thirty_day_volume	The thirty days trade volume in this collection. The timestamp of the data collected is on stats_time
#
# - stats_thirty_day_change	The thirty days trade volume change in this collection. The timestamp of the data collected is on stats_time
#
# - stats_thirty_day_sales	The thirty days number of sales in this collection. The timestamp of the data collected is on stats_time
#
# - stats_thirty_day_average_price	The thirty days average price of the items in this collection. The timestamp of the data collected is on stats_time
#
# - stats_total_volume	The total trade volume in this collection. The timestamp of the data collected is on stats_time
# - stats_total_sales	The total number of sales in this collection. The timestamp of the data collected is on stats_time
# - stats_total_supply	The total number of supply in this collection. The timestamp of the data collected is on stats_time
# - stats_count	The total number of items in this collection.  The timestamp of the data collected is on stats_time
# - stats_num_owners	The total number of owners for all the items in the collection. The timestamp of the data collected is on stats_time
#
# - stats_average_price	The average price of the items in this collection. The timestamp of the data collected is on stats_time
# - stats_market_cap	The market capitalization of the items in this collection. The timestamp of the data collected is on stats_time
#
# - stats_floor_price	The floor price of the items in this collection. The timestamp of the data collected is on stats_time
# - stats_time	The timestamp of collection date for the stats data
# - slug	The collection slug that is used to link to the collection on OpenSea. This value can change by the owner but must be unique across all collection slugs in OpenSea

# %% [markdown]
# - created_date	The date that the collection was created by user
# - description	The description of the collection
# - display_data_card_display_style	The way that the collection's data displayed as, including contain, cover, padded
# - safelist_request_status	The collection's approval status within OpenSea. Can be not_requested (brand new collections), requested (collections that requested safelisting on our site), approved (collections that are approved on our site and can be found in search results), and verified (verified collections)
# - name	The collection name. Typically derived from the first contract imported to the collection but can be changed by the user
# - telegram_url	A boolean whether the collector provide telegram profile url
# - twitter_username	A boolean whether the collector provide twitter account name
# - instagram_username	A boolean whether the collector provide instagram account name
# - medium_username	A boolean whether the collector provide medium account name
# - external_url	External link to the original website for the collection
# - discord_url	The url of the discord, which contains channels serve as the places where community members can discuss particular topic. The number of members could be an important feature of the value of NFT collection

# %%
pip install sweetviz

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pandas_profiling import ProfileReport

# %%
assets_df=pd.read_csv('assets.csv')

# %%
assets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16550 entries, 0 to 16549
# Data columns (total 31 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   token_id                                    16549 non-null  object
#  1   asset_contract_address                      16549 non-null  object
#  2   owner_address                               16549 non-null  object
#  3   collection_slug                             16549 non-null  object
#  4   last_sale_payment_token_id                  8193 non-null   float64
#  5   last_sale_payment_token_symbol              8193 non-null   object
#  6   last_sale_payment_token_address             8193 non-null   object
#  7   last_sale_payment_token_name                8193 non-null   object
#  8   last_sale_payment_token_eth_price           8193 non-null   float64
# ...

# %%
assets_df.head()
# Out:
#                                             token_id  \
# 0  1041544390811223925548137112510456274926830839...
# 1  3408548560580985823464505673624610083362790836...
# 2  2344366250094683526428341084644309510528416437...
# 3  3038784457613480191389558437600275577887949373...
# 4                                               6996
#
#                        asset_contract_address  \
# 0  0x495f947276749ce646f68ac8c248420045cb7b5e
# 1  0x495f947276749ce646f68ac8c248420045cb7b5e
# 2  0x495f947276749ce646f68ac8c248420045cb7b5e
# 3  0x495f947276749ce646f68ac8c248420045cb7b5e
# 4  0x417737d49a175d62625154262d8569d3890425ae
#
#                                 owner_address   collection_slug  \
# 0  0x0000000000000000000000000000000000000000         spiritman
# 1  0x0000000000000000000000000000000000000000       byteosaurus
# 2  0x0000000000000000000000000000000000000000  crypto-totem-nft
# 3  0x0000000000000000000000000000000000000000        ultrapunks
# ...

# %%
assets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16550 entries, 0 to 16549
# Data columns (total 31 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   token_id                                    16549 non-null  object
#  1   asset_contract_address                      16549 non-null  object
#  2   owner_address                               16549 non-null  object
#  3   collection_slug                             16549 non-null  object
#  4   last_sale_payment_token_id                  8193 non-null   float64
#  5   last_sale_payment_token_symbol              8193 non-null   object
#  6   last_sale_payment_token_address             8193 non-null   object
#  7   last_sale_payment_token_name                8193 non-null   object
#  8   last_sale_payment_token_eth_price           8193 non-null   float64
# ...

# %%
assets_df.columns
# Out:
# Index(['token_id', 'asset_contract_address', 'owner_address',
#        'collection_slug', 'last_sale_payment_token_id',
#        'last_sale_payment_token_symbol', 'last_sale_payment_token_address',
#        'last_sale_payment_token_name', 'last_sale_payment_token_eth_price',
#        'last_sale_payment_token_usd_price',
#        'last_sale_transaction_from_account_address',
#        'last_sale_transaction_id', 'last_sale_transaction_timestamp',
#        'last_sale_transaction_to_account_address', 'last_sale_event_timestamp',
#        'last_sale_total_price', 'last_sale_created_date', 'last_sale_quantity',
#        'is_presale', 'traits', 'name', 'num_sales', 'image_url', 'description',
#        'asset_contract_type', 'asset_contract_created_date',
#        'asset_contract_name', 'asset_contract_owner',
#        'asset_contract_dev_seller_fee_basis_points', 'asset_favorites',
#        'asset_category'],
#       dtype='object')

# %% [markdown]
# prof = ProfileReport(assets_df)
# prof.to_file(output_file='assets_ report.html')

# %%
 sourceFile = open('value_counts_assets.txt', 'w')
for col in assets_df.columns:
  
   print('$$$$$$$$$$$$$$$$$$$$$$$$$$$##############%%%%%%%%%%%%% \n',assets_df[col].value_counts(dropna=False),'\n',file = sourceFile)
   print(assets_df[col].unique(),'\n',file=sourceFile) 
 sourceFile.close()

# %% [markdown]
# **observations from Value_counts of assets_df**
#
#
# - last_sale_payment_token_id,last_sale_payment_token_symbol,last_sale_payment_token_address,last_sale_payment_token_name have same information
#
# - following columns have 8358 NaN values
#  - last_sale_payment_token_id,
#  - last_sale_payment_token_symbol,
#  - last_sale_payment_token_address,
#  - last_sale_payment_token_name
#  - last_sale_payment_token_eth_price,
#  - last_sale_payment_token_usd_price,
#  - last_sale_transaction_from_account_address,
#  - last_sale_transaction_id,
#  - last_sale_transaction_timestamp,
#  - last_sale_transaction_to_account_address,
#  - last_sale_event_timestamp,
#  - last_sale_total_price,
#  - last_sale_created_date,
#  - last_sale_quantity
#
# - owner_address has 7762 rows as 0x0000000000000000000000000000000000000000
#
# - asset_contract_name,asset_contract_owner,asset_contract_created_date,asset_contract_address have same information
#
# - there are 6471 rows where owner_address is 0x00 and columns from column_name are NaN

# %%
#verify if same rows are null in all the columns
colum_name=['last_sale_payment_token_id','last_sale_payment_token_symbol','last_sale_payment_token_address','last_sale_payment_token_name','last_sale_payment_token_eth_price','last_sale_payment_token_usd_price','last_sale_transaction_from_account_address', 'last_sale_transaction_id','last_sale_transaction_timestamp','last_sale_transaction_to_account_address','last_sale_event_timestamp','last_sale_total_price','last_sale_created_date','last_sale_quantity']

# %%
assets_df[(assets_df[colum_name].isnull().all(axis=1))&(assets_df['owner_address']=='0x0000000000000000000000000000000000000000')]
# Out:
#                                                 token_id  \
# 0      1041544390811223925548137112510456274926830839...
# 1      3408548560580985823464505673624610083362790836...
# 2      2344366250094683526428341084644309510528416437...
# 3      3038784457613480191389558437600275577887949373...
# 5      7865433927323427708530533979403592174622521535...
# ...                                                  ...
# 11166  1024851593919173023227051548039058883234477915...
# 11167  8485183202000450951038301287420610348165850601...
# 11168  4093867389184081963454834722419751402109922379...
# 11169  8485183202000450951038301287420610348165850601...
# 11170  5676711250177917523140413067965535936311356616...
#
#                            asset_contract_address  \
# 0      0x495f947276749ce646f68ac8c248420045cb7b5e
# 1      0x495f947276749ce646f68ac8c248420045cb7b5e
# 2      0x495f947276749ce646f68ac8c248420045cb7b5e
# 3      0x495f947276749ce646f68ac8c248420045cb7b5e
# ...

# %%
assets_df[assets_df['owner_address']=='0x0000000000000000000000000000000000000000']
# Out:
#                                                 token_id  \
# 0      1041544390811223925548137112510456274926830839...
# 1      3408548560580985823464505673624610083362790836...
# 2      2344366250094683526428341084644309510528416437...
# 3      3038784457613480191389558437600275577887949373...
# 5      7865433927323427708530533979403592174622521535...
# ...                                                  ...
# 16537  5546465704496319681695058728903542806456832097...
# 16540  5546465704496319681695058728903542806456832097...
# 16542  4972498877102577216150974506821100726352090489...
# 16548  5546465704496319681695058728903542806456832097...
# 16549  4988174431192305377471247566851632225166580989...
#
#                            asset_contract_address  \
# 0      0x495f947276749ce646f68ac8c248420045cb7b5e
# 1      0x495f947276749ce646f68ac8c248420045cb7b5e
# 2      0x495f947276749ce646f68ac8c248420045cb7b5e
# 3      0x495f947276749ce646f68ac8c248420045cb7b5e
# ...

# %%
assets_df[['asset_contract_name','asset_contract_owner','asset_contract_created_date','asset_contract_address']].value_counts()
# Out:
# asset_contract_name            asset_contract_owner  asset_contract_created_date  asset_contract_address
# OpenSea Collection             102384.0              2020-12-02T17:40:53.232025   0x495f947276749ce646f68ac8c248420045cb7b5e    6696
# ENS                            111982386.0           2019-05-08T21:59:29.327544   0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85    1101
# CryptoShack                    264752239.0           2022-03-01T01:55:48.858762   0x34997f9c19465ec01b7ed2ab0e61e2a388702790     423
# Dippies                        265998027.0           2022-03-02T13:41:02.605663   0x82f5ef9ddc3d231962ba57a9c2ebb307dc8d26c2     400
# Mavia Land                     255448366.0           2022-02-21T04:37:57.603353   0x4a537f61ef574153664c0dbc8c8f4b900cacbe5d     274
#                                                                                                                                 ...
# ...

# %% [markdown]
# assets_df.drop(columns=['last_sale_payment_token_address',
#        'last_sale_payment_token_name', 'last_sale_payment_token_id'],inplace=True)

# %% [markdown]
# assets_df.drop(columns=['asset_contract_owner','asset_contract_address'],inplace=True)

# %%
assets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16550 entries, 0 to 16549
# Data columns (total 31 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   token_id                                    16549 non-null  object
#  1   asset_contract_address                      16549 non-null  object
#  2   owner_address                               16549 non-null  object
#  3   collection_slug                             16549 non-null  object
#  4   last_sale_payment_token_id                  8193 non-null   float64
#  5   last_sale_payment_token_symbol              8193 non-null   object
#  6   last_sale_payment_token_address             8193 non-null   object
#  7   last_sale_payment_token_name                8193 non-null   object
#  8   last_sale_payment_token_eth_price           8193 non-null   float64
# ...

# %%
import numpy as np

# %% [markdown]
# **EDA ON Assets DATA**

# %% [markdown]
# **1.What asset categories are Created more**

# %%
assets_df.groupby(['asset_category']).size().plot(
    kind='pie', autopct='%1.0f%%',figsize=(20,20))
# Out:
# <AxesSubplot:ylabel='None'>

# %%
assets_df['asset_favorites'].unique()
# Out:
# array(['4', '1', '7', '2', '9', '6', '0', '11', '3', '14', '8', '5', '12',
#        '10', '107', '13', '19', '15', '70', '338', '16', '40', '17', '27',
#        '18', '20', '24', '23', '49', '28', '114', '178', '22', '167',
#        '314', '82', '68', '80', '106', '73', '225', '363', '44', '86',
#        '583', '66', '43', '365', '271', '217', '202', '25', '75', '93',
#        '316', '453', '324', '38', '230', '1.1K', '112', '72', '985',
#        '226', '591', '100', '120', '176', '48', '94', '45', '168', '165',
#        '228', '140', '54', '32', '29', '30', '21', '195', '42', '672',
#        '52', '31', '37', '39', '126', '77', '171', '47', '36', '144',
#        '83', '99', '223', '63', '79', '60', '160', '103', '33', '59',
#        '296', '143', '55', '78', '26', '34', '53', '132', '97', '252',
#        '76', '71', '58', '62', '209', '253', '56', '46', '35', '1.0K',
#        '953', '64', '81', '1.3K', '660', '149', '187', '156', '256',
# ...

# %%
assets_df['asset_favorites'].replace(to_replace={'K':'e+3'},inplace=True,regex=True)
assets_df['asset_favorites']=assets_df['asset_favorites'].astype(float,errors='raise')
assets_df['asset_favorites']=assets_df['asset_favorites'].astype(int,errors='raise')
assets_df['asset_favorites'].unique()
# Out:
# array([     4,      1,      7,      2,      9,      6,      0,     11,
#             3,     14,      8,      5,     12,     10,    107,     13,
#            19,     15,     70,    338,     16,     40,     17,     27,
#            18,     20,     24,     23,     49,     28,    114,    178,
#            22,    167,    314,     82,     68,     80,    106,     73,
#           225,    363,     44,     86,    583,     66,     43,    365,
#           271,    217,    202,     25,     75,     93,    316,    453,
#           324,     38,    230,   1100,    112,     72,    985,    226,
#           591,    100,    120,    176,     48,     94,     45,    168,
#           165,    228,    140,     54,     32,     29,     30,     21,
#           195,     42,    672,     52,     31,     37,     39,    126,
#            77,    171,     47,     36,    144,     83,     99,    223,
#            63,     79,     60,    160,    103,     33,     59,    296,
# ...

# %%
assets_df_clean = assets_df.drop(assets_df[assets_df['asset_favorites']==321200].index)

# %%
assets_df_clean[assets_df_clean['asset_favorites']==5700]
# Out:
#       token_id                      asset_contract_address  \
# 12503        5  0x226bf5293692610692e2c996c9875c914d2a7f73
#
#                                     owner_address  collection_slug  \
# 12503  0x0000000000000000000000000000000000000000  cyber-factory-2
#
#        last_sale_payment_token_id last_sale_payment_token_symbol  \
# 12503                         1.0                            ETH
#
#                   last_sale_payment_token_address  \
# 12503  0x0000000000000000000000000000000000000000
#
#       last_sale_payment_token_name  last_sale_payment_token_eth_price  \
# 12503                        Ether                                1.0
#
#        last_sale_payment_token_usd_price  ... num_sales  \
# 12503                             2630.0  ...    7719.0
#
#                                                image_url  \
# 12503  https://lh3.googleusercontent.com/2YWoVR9HRI5o...
#
#                                              description asset_contract_type  \
# ...

# %% [markdown]
# **2.what collection slug is most favourited**

# %%
assets_df_clean.sort_values('asset_favorites')
# Out:
#       token_id                      asset_contract_address  \
# 8274      1816  0x6faa985dc84619c689509a55cee7ccc36251b4c0
# 5485      3518  0x1fec856e25f757fed06eb90548b0224e91095738
# 5481      3800  0x762bc5880f128dcac29cffdde1cf7ddf4cfc39ee
# 5480      6502  0x762bc5880f128dcac29cffdde1cf7ddf4cfc39ee
# 13547     7240  0xb3b814ccd178de120687a9ad01c6886c56399198
# ...        ...                                         ...
# 12687        1  0xc4c377565a4b9eb6e657c2422bd33b6e4859b041
# 11562    10372  0x76be3b62873462d2142405439777e971754e8e77
# 11677    10371  0x76be3b62873462d2142405439777e971754e8e77
# 12244        1  0xa7206d878c5c3871826dfdb42191c49b1d11f466
# 12503        5  0x226bf5293692610692e2c996c9875c914d2a7f73
#
#                                     owner_address  \
# 8274   0x6c0e616a646dacabbde2165bcb6df89378aa4905
# 5485   0xe6f2ef07a647d7d9ef8d4fe09ecdc72d823416df
# 5481   0xfd4ee475fcd219188580750e8db2cec156d83a45
# 5480   0x48d5449290785bd16f6d8fefe9318c5ee81eb70e
# ...

# %%
assets_df_clean.groupby(['collection_slug'])['asset_favorites'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='collection_slug'>

# %% [markdown]
# **Most favourited collection slugs are parallel alpha ,town-star,the-sandbox-assets**

# %% [markdown]
# **Sales of collection slug**

# %%
assets_df.groupby(['collection_slug'])['num_sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='collection_slug'>

# %% [markdown]
# **parallel alpha ,town-star,lostpets have seen more sales**
#
# MOst favorited have seen more sales

# %% [markdown]
# **Revenue generated from sale of collections**

# %%
assets_df.groupby(['collection_slug'])['last_sale_payment_token_usd_price'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='collection_slug'>

# %% [markdown]
# **collections from ens,cryptoshack,dippie has generated more revenue**

# %% [markdown]
# **which type of asset is generating more money**

# %%
assets_df.groupby(['asset_category'])['last_sale_payment_token_usd_price'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='asset_category'>

# %% [markdown]
# **which type of assets have more sales**

# %%
assets_df.groupby(['asset_category'])['num_sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='asset_category'>

# %%
assets_df.groupby(['asset_contract_type'])['num_sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(8,10))
# Out:
# <AxesSubplot:xlabel='asset_contract_type'>

# %%
assets_df.groupby(['asset_contract_type'])['last_sale_payment_token_usd_price'].sum().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(8,8))
# Out:
# <AxesSubplot:xlabel='asset_contract_type'>

# %% [markdown]
# **sales are more in  trading-cards ,virtual-worlds**

# %% [markdown]
# **no of fungible and semi fungible assets in each asset category**

# %%
assets_df.groupby(['asset_category','asset_contract_type']).size().sort_values(ascending=False).unstack().head(10).plot(kind='bar')
plt.savefig('Fun,semi fung in asset categories.png')
plt.show()

# %%
assets_df[['name','collection_slug','asset_contract_name']].nunique()
# Out:
# name                   15057
# collection_slug         1426
# asset_contract_name      932
# dtype: int64

# %% [markdown]
# **number of contracts created in a given time**

# %%
assets_df['asset_contract_created_date'].unique()
# Out:
# array(['2020-12-02T17:40:53.232025', '2022-02-02T08:11:36.815197',
#        '2022-03-02T13:41:02.605663', '2022-01-31T17:21:30.327073',
#        '2020-12-12T13:31:36.385177', '2022-02-12T08:38:02.531835',
#        '2022-02-25T20:31:08.837213', '2022-01-28T08:54:53.912769',
#        '2022-03-04T09:51:35.116630', '2021-11-04T00:35:07.285763',
#        '2021-12-19T07:01:08.628732', '2022-02-28T13:12:34.929582',
#        '2021-12-10T04:05:14.241055', '2022-02-25T12:06:23.050935',
#        '2021-10-30T18:12:11.833573', '2022-01-15T00:57:00.586766',
#        '2019-09-26T06:17:45.237752', '2021-09-16T19:42:46.652443',
#        '2022-02-21T16:46:13.165609', '2021-11-26T16:12:18.106031',
#        '2022-02-14T12:36:54.161167', '2021-10-29T00:43:08.179099',
#        '2021-12-31T08:11:31.376814', '2022-01-20T09:55:05.012229',
#        '2021-01-26T00:01:44.023638', '2021-09-02T08:40:17.470418',
#        '2021-12-25T16:28:49.864843', '2022-01-11T08:04:57.760945',
# ...

# %%
pd.to_datetime(assets_df['asset_contract_created_date'])
assets_df.loc[:,'created_Time'] = pd.to_datetime(assets_df['asset_contract_created_date'])




assets_df['year_created'] = pd.to_datetime(assets_df['created_Time']).dt.year
assets_df['year_created'] = assets_df['year_created'].astype('Int64')
assets_df['Month_created']=pd.to_datetime(assets_df['created_Time']).dt.month
assets_df['Month_created'] = assets_df['Month_created'].astype('Int64')
assets_df['day_created']=pd.to_datetime(assets_df['created_Time']).dt.day
assets_df['day_created'] = assets_df['day_created'].astype('Int64')
print(assets_df.info())
assets_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16550 entries, 0 to 16549
# Data columns (total 35 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   token_id                                    16549 non-null  object
#  1   asset_contract_address                      16549 non-null  object
#  2   owner_address                               16549 non-null  object
#  3   collection_slug                             16549 non-null  object
#  4   last_sale_payment_token_id                  8193 non-null   float64
#  5   last_sale_payment_token_symbol              8193 non-null   object
#  6   last_sale_payment_token_address             8193 non-null   object
#  7   last_sale_payment_token_name                8193 non-null   object
#  8   last_sale_payment_token_eth_price           8193 non-null   float64
# ...

# %%
assets_df[assets_df['asset_contract_created_date'].isnull()]
# Out:
#     token_id asset_contract_address owner_address collection_slug  \
# 757      NaN                    NaN           NaN             NaN
#
#      last_sale_payment_token_id last_sale_payment_token_symbol  \
# 757                         NaN                            NaN
#
#     last_sale_payment_token_address last_sale_payment_token_name  \
# 757                             NaN                          NaN
#
#      last_sale_payment_token_eth_price  last_sale_payment_token_usd_price  \
# 757                                NaN                                NaN
#
#      ... asset_contract_created_date  asset_contract_name  \
# 757  ...                         NaN                  NaN
#
#     asset_contract_owner asset_contract_dev_seller_fee_basis_points  \
# 757                  NaN                                        NaN
#
#     asset_favorites asset_category created_Time  year_created Month_created  \
# ...

# %%
assets_df.drop(757,inplace=True)

# %%
year_l=[2018,2019,2020,2021,2022]
fig,ax=  plt.subplots(nrows=2,ncols=3, sharex=False, sharey= False, figsize=(24,16)) 
ax = ax.flatten()
ind=[0,1,2,3,4,5]
for y,i in  zip(year_l,ind) :
    assets_df[(assets_df['year_created'])==y].groupby(['Month_created'])['asset_contract_owner'].count().plot(kind='line',figsize=(15,10),ax=ax[i],linestyle='--', marker='o',use_index=True,legend=True)
    assets_df[(assets_df['year_sale'])==y].groupby(['Month_sale'])['last_sale_quantity'].count().plot(kind='line',figsize=(15,10),ax=ax[i],linestyle='--',color='red', marker='o',use_index=True,legend=True)
    ax[i].set_xlabel(y, fontsize=1)
    ax[i].set_xlabel(y, fontsize=15)

plt.show()
plt.savefig('Number of NFTS created each year.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year_sale'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
assets_df.groupby(['year_created'])['asset_contract_owner'].count().plot(kind='line',fa
plt.show()

# %%
assets_df['last_sale_transaction_timestamp'].unique()

# %%
pd.to_datetime(assets_df['last_sale_transaction_timestamp'])
assets_df.loc[:,'sale_Time'] = pd.to_datetime(assets_df['last_sale_transaction_timestamp'])




assets_df['year_sale'] = pd.to_datetime(assets_df['sale_Time']).dt.year
assets_df['year_sale'] = assets_df['year_sale'].astype('Int64')
assets_df['Month_sale']=pd.to_datetime(assets_df['sale_Time']).dt.month
assets_df['Month_sale'] = assets_df['Month_sale'].astype('Int64')
assets_df['day_sale']=pd.to_datetime(assets_df['sale_Time']).dt.day
assets_df['day_sale'] = assets_df['day_sale'].astype('Int64')
print(assets_df.info())
assets_df

# %%
assets_df['year_sale'].unique()

# %%
assets_df[['last_sale_event_timestamp','last_sale_transaction_timestamp','last_sale_quantity']]
assets_df['last_sale_quantity'].value_counts()

# %%
assets_df['num_sales'].value_counts()

# %%
year_l=[2018,2019,2020,2021,2022]
fig,ax=  plt.subplots(nrows=2,ncols=3, sharex=False, sharey= False, figsize=(24,16)) 
ax = ax.flatten()
ind=[0,1,2,3,4,5]
for y,i in  zip(year_l,ind) :
    assets_df[(assets_df['year_sale'])==y].groupby(['Month_sale'])['last_sale_transaction_id'].count().plot(kind='line',figsize=(15,10),ax=ax[i],linestyle='--', marker='o',use_index=True,legend=False)
    ax[i].set_xlabel(y, fontsize=15)

plt.show()
plt.savefig('Number of NFTS sale each year.png')

# %%
year_l=[2018,2019,2020,2021,2022]
fig,ax=  plt.subplots(nrows=2,ncols=3, sharex=False, sharey= False, figsize=(24,16)) 
ax = ax.flatten()
ind=[0,1,2,3,4,5]
for y,i in  zip(year_l,ind) :
    assets_df[(assets_df['year_sale'])==y].groupby(['Month_sale'])['last_sale_transaction_id'].count().plot(kind='line',figsize=(15,10),ax=ax[i],linestyle='--', marker='o',use_index=True,legend=False)
    ax[i].set_xlabel(y, fontsize=15)

plt.show()
plt.savefig('Number of NFTS sale each year.png')

# %%
year_l=[2018,2019,2020,2021,2022]
fig,ax=  plt.subplots(nrows=2,ncols=3, sharex=False, sharey= False, figsize=(24,16)) 
ax = ax.flatten()
ind=[0,1,2,3,4,5]
for y,i in  zip(year_l,ind) :
    assets_df[(assets_df['year_sale'])==y].groupby(['Month_sale'])['num_sales'].count().plot(kind='line',figsize=(15,10),ax=ax[i],linestyle='--', marker='o',use_index=True,legend=False)
    ax[i].set_xlabel(y, fontsize=15)

plt.show()
plt.savefig('Number of NFTS sale each year.png')

# %%
assets_df['traits']
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                   [{'trait_type': 'smile', 'value': 'laughing', 'display_type': None, 'max_value': None, 'trait_count': 6001, 'order': None}, {'trait_type': 'pet', 'value': 'Platypus Purle', 'display_type': None, 'max_value': None, 'trait_count': 678, 'order': None}, {'trait_type': 'eye', 'value': 'Purple', 'display_type': None, 'max_value': None, 'trait_count': 3552, 'order': None}, {'trait_type': 'body', 'value': 'Orange', 'display_type': None, 'max_value': None, 'trait_count': 1849, 'order': None}, {'trait_type': 'cloth', 'value': 'Body Suit1', 'display_type': None, 'max_value': None, 'trait_count': 656, 'order': None}, {'trait_type': 'hair', 'value': 'hairstyle4 G
# ...

# %%
traits_df=pd.DataFrame(assets_df['traits'])
traits_df.drop(traits_df[traits_df['traits']=='[]'].index,inplace=True)
traits_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
myvar_list = traits_df['traits'].tolist()
myvar_list[1]
# Out:
# "[{'trait_type': 'background', 'value': 'pink', 'display_type': None, 'max_value': None, 'trait_count': 1331, 'order': None}, {'trait_type': 'eyes', 'value': 'suspicious', 'display_type': None, 'max_value': None, 'trait_count': 617, 'order': None}, {'trait_type': 'glasses', 'value': 'round', 'display_type': None, 'max_value': None, 'trait_count': 735, 'order': None}, {'trait_type': 'mouth', 'value': 'awkward smile', 'display_type': None, 'max_value': None, 'trait_count': 805, 'order': None}, {'trait_type': 'body', 'value': 'scarred', 'display_type': None, 'max_value': None, 'trait_count': 292, 'order': None}, {'trait_type': 'head', 'value': 'police', 'display_type': None, 'max_value': None, 'trait_count': 277, 'order': None}, {'trait_type': 'earring', 'value': 'cogwheel', 'display_type': None, 'max_value': None, 'trait_count': 806, 'order': None}, {'trait_type': 'clothes', 'value': 'target', 'display_type': None, 'max_value': None, 'trait_count': 336, 'order': None}, {'trait_type': '
# ...

# %%
from collections import defaultdict
import ast
new_df=pd.DataFrame(columns=['trait'])
i=0
new_df
  #new_df.loc[0]=ast.literal_eval(myvar_list[0])
    

list1=ast.literal_eval(myvar_list[0])
new_df.loc[0]=list1[0]
new_df
# Out:
#   trait
# 0   NaN

# %%
def build_df(list1,df):
  
    for j in list1:
        values_to_add = j
        row_to_add = pd.Series(values_to_add, name='j')
        #print(row_to_add)
        df = df.append(row_to_add)

# %%
df=pd.DataFrame()
for item in myvar_list:
    list1=ast.literal_eval(item)
    build_df(list1,df)
df.head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7252/884271073.py in <module>
#       2 for item in myvar_list:
#       3     list1=ast.literal_eval(item)
# ----> 4     build_df(list1,df)
#       5 df.head(50)
#
# ~\AppData\Local\Temp/ipykernel_7252/1309998675.py in build_df(list1, df)
#       5         row_to_add = pd.Series(values_to_add, name='j')
#       6         #print(row_to_add)
# ----> 7         df = df.append(row_to_add)
#       8
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    8963             to_concat = [self, other]
#    8964         return (
# -> 8965             concat(
#    8966                 to_concat,
#    8967                 ignore_index=ignore_index,
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
# ...
